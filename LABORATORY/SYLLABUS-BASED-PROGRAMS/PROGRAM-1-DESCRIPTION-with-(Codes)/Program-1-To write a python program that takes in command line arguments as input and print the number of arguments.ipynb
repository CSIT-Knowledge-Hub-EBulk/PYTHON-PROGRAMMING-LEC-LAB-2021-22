# %%
import sys

# %%
print("This is the name of the script:", sys.argv[0])
# Out:
# This is the name of the script: /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py

# %%
print("Number of arguments:", len(sys.argv))
# Out:
# Number of arguments: 3

# %%
print("The arguments are:" , str(sys.argv))
# Out:
# The arguments are: ['/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py', '-f', '/root/.local/share/jupyter/runtime/kernel-e63330f4-c1d7-432f-a6fb-6ef73a3663b5.json']
